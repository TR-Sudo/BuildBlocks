# %% [markdown]
# # Setup and Load Data

# %%
import tensorflow as tf
import os

# %%
#To avoid out of memory errors by setting GPU memory consumption growth
gpus=tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# %% [markdown]
# # Removing dodgy images

# %%
import cv2
import imghdr
from matplotlib import pyplot as plt

# %%
data_dir='data'

# %%
image_exts=['jpeg','jpg','bmp','png']

# %%
os.listdir(data_dir)
# Out:
# ['Happy', 'Sad']

# %%
# Returns every image in the files
#os.listdir(os.path.join(data_dir,'Happy'))

# %%
img=cv2.imread(os.path.join('data','happy','happiness.jpg'))
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
for image in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir,image_class)):
        image_path=os.path.join(data_dir,image_class,image)
        try:
            img=cv2.imread(image_path)#check if it reads into cv2
            tip=imghdr.what(image_path)
            if tip not in image_exts:
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Issue with image {}'.format(image_path))

# %% [markdown]
# ## Load Data & Preprocessing

# %%
import numpy as np

# %%
data=tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 209 files belonging to 2 classes.

# %%
data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_iterator=data.as_numpy_iterator()

# %%
#get another batch from the iterator
batch = data_iterator.next()
batch[0].shape #32 is batch size, 256x256,3 is color images
# Out:
# (32, 256, 256, 3)

# %%
fig,ax = plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])
    
#From images class 1 is sad and 0 is happy

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# ## Scale Data

# %%
data=data.map(lambda x,y: (x/255,y))

# %%
data.as_numpy_iterator().next()[0].max()
# Out:
# 1.0

# %%
fig,ax = plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# ## Split Data

# %%
len(data)#Total batches
# Out:
# 7

# %%
train_size=int(len(data)*.7)
#Training size batch
train_size
# Out:
# 4

# %%
val_size=int(len(data)*.2)+1
#Validation size batch
val_size
# Out:
# 2

# %%
test_size=int(len(data)*.1)+1
#Test size batch
test_size
# Out:
# 1

# %%
train=data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # Deep Model

# %% [markdown]
# ## Build Deep Learning Model

# %%
from tensorflow.keras.models import Sequential
#Layers
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

# %%
model=Sequential()

# %%
model.add(Conv2D(16,(3,3),1,activation='relu',input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(36,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile('adam',loss=tf.losses.BinaryCrossentropy(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 254, 254, 16)      448
#
#  max_pooling2d_7 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 125, 125, 36)      5220
#
#  max_pooling2d_8 (MaxPooling  (None, 62, 62, 36)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 60, 60, 16)        5200
#
#  max_pooling2d_9 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 14400)             0
#
#  dense_4 (Dense)             (None, 256)               3686656
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,697,781
# Trainable params: 3,697,781
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train,epochs=20,validation_data=val,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 4/4 [==============================] - 3s 540ms/step - loss: 0.7311 - accuracy: 0.5547 - val_loss: 0.6313 - val_accuracy: 0.7969
# Epoch 2/20
# 4/4 [==============================] - 2s 515ms/step - loss: 0.5859 - accuracy: 0.6797 - val_loss: 0.4987 - val_accuracy: 0.6875
# Epoch 3/20
# 4/4 [==============================] - 2s 500ms/step - loss: 0.4557 - accuracy: 0.7031 - val_loss: 0.5377 - val_accuracy: 0.6875
# Epoch 4/20
# 4/4 [==============================] - 2s 485ms/step - loss: 0.5236 - accuracy: 0.7188 - val_loss: 0.5674 - val_accuracy: 0.6250
# Epoch 5/20
# 4/4 [==============================] - 2s 484ms/step - loss: 0.4740 - accuracy: 0.7422 - val_loss: 0.4350 - val_accuracy: 0.8438
# Epoch 6/20
# 4/4 [==============================] - 2s 481ms/step - loss: 0.4456 - accuracy: 0.8828 - val_loss: 0.4010 - val_accuracy: 0.9062
# Epoch 7/20
# 4/4 [==============================] - 2s 486ms/step - loss: 0.3363 - accuracy: 0.8672 - val_loss: 0.2941 - val_accuracy: 0.8594
# Epoch 8/20
# 4/4 [==============================] - 2s 485ms/step - loss: 0.2884 - accuracy: 0.8906 - val_loss: 0.2144 - val_accuracy: 0.8906
# Epoch 9/20
# 4/4 [==============================] - 2s 484ms/step - loss: 0.2119 - accuracy: 0.9297 - val_loss: 0.1581 - val_accuracy: 0.9688
# Epoch 10/20
# 4/4 [==============================] - 2s 482ms/step - loss: 0.1194 - accuracy: 0.9922 - val_loss: 0.1599 - val_accuracy: 0.9375
# Epoch 11/20
# 4/4 [==============================] - 2s 502ms/step - loss: 0.0838 - accuracy: 0.9844 - val_loss: 0.1021 - val_accuracy: 0.9844
# Epoch 12/20
# 4/4 [==============================] - 2s 483ms/step - loss: 0.0917 - accuracy: 0.9688 - val_loss: 0.1868 - val_accuracy: 0.9688
# Epoch 13/20
# 4/4 [==============================] - 2s 489ms/step - loss: 0.0930 - accuracy: 0.9766 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 14/20
# 4/4 [==============================] - 2s 488ms/step - loss: 0.0474 - accuracy: 0.9844 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 15/20
# 4/4 [==============================] - 2s 496ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 16/20
# 4/4 [==============================] - 2s 497ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 17/20
# 4/4 [==============================] - 2s 503ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 18/20
# 4/4 [==============================] - 2s 500ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 19/20
# 4/4 [==============================] - 2s 496ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 20/20
# 4/4 [==============================] - 2s 490ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000

# %% [markdown]
# ## Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'],color='teal',label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val_loss')
fig.suptitle('Loss',fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'],color='teal',label='accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='val_accuracy')
fig.suptitle('Accuracy',fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Evaluate

# %%
from tensorflow.keras.metrics import Precision,Recall,BinaryAccuracy

# %%
pre=Precision()
re=Recall()
acc=BinaryAccuracy()

# %%
len(test)
# Out:
# 1

# %%
for batch in test.as_numpy_iterator():
    X,y = batch
    yhat=model.predict(X)
    pre.update_state(y,yhat)
    re.update_state(y,yhat)
    acc.update_state(y,yhat)
# Out:
# 1/1 [==============================] - 0s 70ms/step

# %%
print(f'Precision:{pre.result().numpy()},Recall:{re.result().numpy()},Accuracy:{acc.result().numpy()}')
# Out:
# Precision:1.0,Recall:1.0,Accuracy:1.0

# %% [markdown]
# ## Test images

# %%
img = cv2.imread('happytest.jfif')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize=tf.image.resize(img,(256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255,0))
# Out:
# 1/1 [==============================] - 0s 17ms/step

# %%
yhat
# Out:
# array([[0.9970491]], dtype=float32)

# %%
def returnans(yhat):
    if (yhat>0.5):
        print("Happy")
    else:
        print("sad")
# Out:
# Happy

# %%
img = cv2.imread('sadtest.jfif')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize=tf.image.resize(img,(256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255,0))
yhat
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[0.99998695]], dtype=float32)
